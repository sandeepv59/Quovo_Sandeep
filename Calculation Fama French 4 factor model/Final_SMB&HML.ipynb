# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# height has been deprecated.

# %% [markdown]
# ## 1. Read Compustat Data

# %%
compustat_data = pd.read_csv("compustat_data_new.csv")[['LPERMNO','LPERMCO','fyear','seq']]

# %%
compustat_data.head()
# Out:
#    LPERMNO  LPERMCO  fyear     seq
# 0    25881    23369   1970  10.544
# 1    25881    23369   1971   8.382
# 2    25881    23369   1972   7.021
# 3    25881    23369   1973   8.567
# 4    25881    23369   1974  10.257

# %%
compustat_data.isnull().sum()
# Out:
# LPERMNO        0
# LPERMCO        0
# fyear          1
# seq        28188
# dtype: int64

# %%
compustat_data.dropna(subset=['fyear', 'seq'], how="any",inplace=True)

# %%
compustat_data.sort_values(by='fyear', inplace=True)

# %% [markdown]
# If we see the last row of the below table, we can see that the equity changes for different LPERMNO for the
# same company. So consider that LPERMNO, LPERMCO as the combination that captures the Book/Market Ratio

# %%
compustat_data[compustat_data.LPERMCO == 45301].tail(15)
# Out:
#         LPERMNO  LPERMCO  fyear      seq
# 271644    90228    45301   2011   2805.4
# 271648    90866    45301   2012   2210.0
# 271649    90227    45301   2012   2210.0
# 271647    90228    45301   2012   2210.0
# 271652    90227    45301   2013  12025.8
# 271650    90228    45301   2013  12025.8
# 271651    90866    45301   2013  12025.8
# 271655    90227    45301   2014  14714.5
# 271653    90228    45301   2014  14714.5
# 271654    90866    45301   2014  14714.5
# 201163    15403    45301   2015    206.4
# 201162    15402    45301   2015    206.4
# 271656    90228    45301   2015  10446.0
# 271657    90866    45301   2015  10446.0
# 271658    90227    45301   2015  10446.0

# %%
def get_prev_book_value(series):
    prev_year = series['fyear']
    shifted_series = series.shift(1)
    correct_rows = (prev_year == (shifted_series['fyear']+1))
    return shifted_series.ix[correct_rows,'seq']

# %%
compustat_data['prev_seq'] = compustat_data.groupby(['LPERMCO','LPERMNO'],group_keys = False).apply(get_prev_book_value)

# %%
compustat_data[compustat_data.LPERMCO == 22287]
# Out:
#        LPERMNO  LPERMCO  fyear     seq  prev_seq
# 35863    11543    22287   1960  39.110       NaN
# 35864    11543    22287   1961  36.379    39.110
# 35865    11543    22287   1962  35.485    36.379
# 35866    11543    22287   1963  29.701    35.485
# 35867    11543    22287   1964  31.454    29.701
# 35868    11543    22287   1965  12.142    31.454
# 35869    11543    22287   1966  14.178    12.142
# 35870    11543    22287   1967  20.958    14.178
# 35871    11543    22287   1968  38.601    20.958

# %% [markdown]
# ### Delete those rows with no prev year seq data

# %%
compustat_data.dropna(subset=['prev_seq'],inplace=True)

# %%
compustat_data.drop('prev_seq', axis = 1, inplace=True)

# %%
compustat_data.rename(columns = {"LPERMCO":"PERMCO","LPERMNO":"PERMNO"}, inplace=True)

# %%
compustat_data.head()
# Out:
#         PERMNO  PERMCO  fyear      seq
# 82374    19043   22890   1960  199.898
# 58661    25160   20847   1961   65.602
# 82375    19043   22890   1961  211.436
# 35864    11543   22287   1961   36.379
# 140592   19940   22960   1961  249.852

# %% [markdown]
# # 2. CRSP Data

# %%
crsp_data = pd.read_csv("crsp_data_new.csv",parse_dates=['date'])

# %%
crsp_data.head(2)
# Out:
#    PERMNO       date  SHRCD SICCD TICKER                     COMNAM  PERMCO     CUSIP DLRETX DLRET    PRC        RET  SHROUT       RETX
# 0   10000 1986-01-31     10  3990  OMFGA  OPTIMUM MANUFACTURING INC    7952  68391610    NaN   NaN -4.375          C    3680          C
# 1   10000 1986-02-28     10  3990  OMFGA  OPTIMUM MANUFACTURING INC    7952  68391610    NaN   NaN -3.250  -0.257143    3680  -0.257143

# %%
crsp_data.dtypes
# Out:
# PERMNO             int64
# date      datetime64[ns]
# SHRCD              int64
# SICCD             object
# TICKER            object
# COMNAM            object
# PERMCO             int64
# CUSIP             object
# DLRETX            object
# DLRET             object
# PRC              float64
# RET               object
# SHROUT           float64
# RETX              object
# dtype: object

# %%
crsp_data.isnull().sum()
# Out:
# PERMNO          0
# date            0
# SHRCD           0
# SICCD           0
# TICKER     220551
# COMNAM          0
# PERMCO          0
# CUSIP           0
# DLRETX    3225637
# DLRET     3225637
# PRC         90482
# RET         39723
# SHROUT       4443
# RETX        39723
# dtype: int64

# %% [markdown]
# ### Calculating Year and month from the data

# %%
crsp_data['year'] = crsp_data.date.dt.year
crsp_data['month'] = crsp_data.date.dt.month

# %% [markdown]
# ## CRSP Data Cleaning

# %% [markdown]
# ### a. Convert the Price to its absolute value

# %%
crsp_data['PRC'] = crsp_data.PRC.abs()

# %% [markdown]
# ### b. Convert the Ret , Retx , DLRet , DLRetx which have codes to NaN

# %%
crsp_data['DLRET'] = pd.to_numeric(crsp_data.DLRET,errors='coerce')
crsp_data['RET'] = pd.to_numeric(crsp_data.RET, errors = 'coerce')
crsp_data['DLRETX'] = pd.to_numeric(crsp_data.DLRETX,errors='coerce')
crsp_data['RETX'] = pd.to_numeric(crsp_data.RETX, errors = 'coerce')

# %%
crsp_data.isnull().sum()
# Out:
# PERMNO          0
# date            0
# SHRCD           0
# SICCD           0
# TICKER     220551
# COMNAM          0
# PERMCO          0
# CUSIP           0
# DLRETX    3229538
# DLRET     3229538
# PRC         90482
# RET        114897
# SHROUT       4443
# RETX       114897
# year            0
# month           0
# dtype: int64

# %% [markdown]
# Number of NaN s in Ret and RetX increases because it used to have alphabet codes when the company gets delisted.

# %% [markdown]
# ### Where Ret is not available, copy DLRet. Same is the case for RetX, DLRetX pair

# %%
crsp_data.ix[crsp_data.DLRET.notnull(),'RET'] = crsp_data.ix[crsp_data.DLRET.notnull(),'DLRET']
crsp_data.ix[crsp_data.DLRETX.notnull(),'RETX'] = crsp_data.ix[crsp_data.DLRETX.notnull(),'DLRETX']

# %%
crsp_data.isnull().sum()
# Out:
# PERMNO          0
# date            0
# SHRCD           0
# SICCD           0
# TICKER     220551
# COMNAM          0
# PERMCO          0
# CUSIP           0
# DLRETX    3229538
# DLRET     3229538
# PRC         90482
# RET         97272
# SHROUT       4443
# RETX        97272
# year            0
# month           0
# dtype: int64

# %% [markdown]
# ### Calculate the Market Cap for the rows of data

# %%
crsp_data['market_cap'] = (crsp_data['SHROUT'] * crsp_data['PRC'])/1000

# %% [markdown]
# ### For each row the recent fiscal year is current_year minus one.

# %%
crsp_data['fyear'] = crsp_data['year']- 1

# %% [markdown]
# #### Check for duplicate rows

# %%
crsp_data.duplicated(subset=['PERMCO','PERMNO','date']).sum()
# Out:
# 0

# %% [markdown]
# ### Getting Market Cap for each row in Compustat by merging with CRSP.
# ### For each fyear data, get the market cap in december same year
# #### Merging on PERMCO,PERMNO, year basis

# %%
compustat_data = pd.merge(compustat_data, crsp_data.ix[crsp_data.month == 12, ['PERMCO','PERMNO','year','market_cap']],
                         left_on = ['PERMCO','PERMNO','fyear'], right_on = ['PERMCO','PERMNO','year'], suffixes = ['_comp','_crsp'],
                         how = 'left')

# %%
compustat_data.isnull().sum()
# Out:
# PERMNO            0
# PERMCO            0
# fyear             0
# seq               0
# year          29466
# market_cap    32212
# dtype: int64

# %% [markdown]
# ### some rows don't have year data this means for those rows, market cap data is not available. So delete that data.

# %%
compustat_data.dropna(subset=['year'], inplace=True)

# %%
compustat_data.isnull().sum()
# Out:
# PERMNO           0
# PERMCO           0
# fyear            0
# seq              0
# year             0
# market_cap    2746
# dtype: int64

# %% [markdown]
# Most of the above market_cap NaN rows are from December 2015. Because the downloaded dataset is upto dec 2015. Many
# companies does not have Price data, so market cap is not available. Drop these rows as well.

# %%
compustat_data.dropna(subset=['market_cap'], inplace=True)

# %%
compustat_data['BMR'] = compustat_data.seq/compustat_data.market_cap

# %%
compustat_data.head()
# Out:
#    PERMNO  PERMCO  fyear      seq  year  market_cap       BMR
# 0   19043   22890   1960  199.898  1960   260.77500  0.766554
# 1   25160   20847   1961   65.602  1961    57.72000  1.136556
# 2   19043   22890   1961  211.436  1961   362.01850  0.584048
# 3   11543   22287   1961   36.379  1961    19.36675  1.878426
# 4   19940   22960   1961  249.852  1961   491.73900  0.508099

# %% [markdown]
# ### Merge CRSP Data with the Compustat Data to get the corresponding fyear BMR
# #### Merge Using Company Number , Financial year ,PERMNO

# %%
crsp_data = pd.merge(crsp_data, compustat_data[['PERMCO','PERMNO','fyear','BMR']],
         left_on = ['PERMCO','PERMNO', 'fyear'], right_on =['PERMCO','PERMNO', 'fyear'], how = 'left' )

# %% [markdown]
# # 3. Creating Portfolio Weights at the end of June

# %% [markdown]
# ### Get the BMR and Marketcap for all the stocks at the end of june

# %%
june_data = crsp_data.ix[crsp_data.month == 6, ['PERMNO','PERMCO','year','market_cap','BMR']]

# %% [markdown]
# ### Delete those rows which does not have Market cap and BMR

# %%
june_data.dropna(subset=['market_cap','BMR'], how = 'any', inplace=True)

# %%
june_data.duplicated(subset= ['PERMCO','PERMNO','year']).sum()
# Out:
# 0

# %% [markdown]
# #### No duplicate rows in the above dataset

# %%
june_data.isnull().sum()
# Out:
# PERMNO        0
# PERMCO        0
# year          0
# market_cap    0
# BMR           0
# dtype: int64

# %% [markdown]
# ## Calculating Size here
# #### ranks are in ascending order here

# %%
june_data['market_cap_percentile'] = june_data[['year',
                                                'market_cap']].groupby('year').rank(pct=True)['market_cap']

# %%
june_data['Size'] = np.where(june_data['market_cap_percentile']>=0.8, "Big",'Small')

# %%
june_data.head()
# Out:
#     PERMNO  PERMCO  year  market_cap       BMR  market_cap_percentile   Size
# 47   10001    7953  1988     6.20000  0.921242               0.157191  Small
# 59   10001    7953  1989     7.00700  0.866360               0.175465  Small
# 71   10001    7953  1990    10.05225  0.610857               0.237179  Small
# 83   10001    7953  1991    11.26650  0.716968               0.267385  Small
# 95   10001    7953  1992    12.63125  0.512077               0.233716  Small

# %% [markdown]
# ## Calculating Value here

# %%
june_data['Value_percentile']=june_data[['year','Size','BMR']].groupby(['year','Size']).rank(pct = True)['BMR']

# %%
june_data['Value']  = np.nan

# %%
june_data.ix[june_data.Value_percentile <= 0.30,'Value'] = "Growth"
june_data.ix[june_data.Value_percentile >= 0.70,'Value'] = "Value"
june_data.ix[np.logical_and(june_data.Value_percentile < 0.70,
                            june_data.Value_percentile > 0.30) ,'Value'] = 'Neutral'

# %% [markdown]
# ### Verifying the percentiles for 2015 year

# %%
pd.pivot_table(june_data[june_data.year == 2015], index=['Size','Value'],aggfunc=len,margins=True)
# Out:
#                 BMR  PERMCO  PERMNO  Value_percentile  market_cap  market_cap_percentile  year
# Size  Value
# Big   Growth    201     201     201               201         201                    201   201
#       Neutral   267     267     267               267         267                    267   267
#       Value     202     202     202               202         202                    202   202
# Small Growth    802     802     802               802         802                    802   802
#       Neutral  1070    1070    1070              1070        1070                   1070  1070
#       Value     803     803     803               803         803                    803   803
# All            3345    3345    3345              3345        3345                   3345  3345

# %%
june_data = june_data.ix[:,['PERMNO','PERMCO','year','Size','Value','market_cap']]

# %% [markdown]
# ## Calculating the value weighted portfolio here

# %%
june_data['port_weights'] =  june_data[['year','Size','Value',
                  'market_cap']].groupby(['year',
                'Size','Value'],group_keys = False).apply(lambda x: x['market_cap']/(x['market_cap'].sum()))

# %% [markdown]
# ### Verifying the portfolio weights here for all the portfolio for year 2015

# %%
pd.pivot_table(june_data[(june_data.year == 2015 ) ],index=['Size','Value'],aggfunc=np.sum,margins=True)['port_weights']
# Out:
# Size   Value
# Big    Growth     1
#        Neutral    1
#        Value      1
# Small  Growth     1
#        Neutral    1
#        Value      1
# All               6
# Name: port_weights, dtype: float64

# %% [markdown]
# ## Merge with CRSP

# %% [markdown]
# #### Creating Portfolio year and Portfolio month here

# %% [markdown]
# portfolio year is the year when the portfolio weights were decided.
# portfolio month is the month from the constution of the portfolio.

# %%
crsp_data['portfolio_year'] = np.nan
crsp_data.ix[crsp_data.month > 6,'portfolio_year'] = crsp_data.ix[crsp_data.month > 6,'year']
crsp_data.ix[crsp_data.month <= 6,'portfolio_year'] = crsp_data.ix[crsp_data.month <= 6,'year'] - 1

# %%
crsp_data['portfolio_month'] = np.nan
crsp_data.ix[crsp_data.month > 6,'portfolio_month'] = crsp_data.ix[crsp_data.month > 6,'month'] -6 
crsp_data.ix[crsp_data.month <= 6,'portfolio_month'] = crsp_data.ix[crsp_data.month <= 6,'month'] +6

# %%
crsp_data = pd.merge(crsp_data, june_data[['PERMCO','PERMNO','year','Size','Value','port_weights']],
        left_on = ['PERMCO','PERMNO','portfolio_year'],
        right_on = ['PERMCO','PERMNO','year'],how = "left")

# %% [markdown]
# #### Delete those rows for which port_weights are not available

# %%
crsp_data.dropna(subset=['port_weights'],inplace=True)

# %%
crsp_data.isnull().sum()
# Out:
# PERMNO                   0
# date                     0
# SHRCD                    0
# SICCD                    0
# TICKER                6966
# COMNAM                   0
# PERMCO                   0
# CUSIP                    0
# DLRETX             2203658
# DLRET              2203658
# PRC                  20313
# RET                   8018
# SHROUT                1821
# RETX                  8018
# year_x                   0
# month                    0
# market_cap           20313
# fyear                    0
# BMR                  11266
# portfolio_year           0
# portfolio_month          0
# year_y                   0
# Size                     0
# Value                    0
# port_weights             0
# dtype: int64

# %%
crsp_data[crsp_data.BMR.isnull()]['portfolio_month'].unique()
# Out:
# array([  7.,   8.,   9.,  10.,  11.,  12.])

# %% [markdown]
# The NaN in market_cap and BMR is due to fact that they are not availabe for last fiscal year. Whereas the stocks are included last year, which used the previous year stats to include in the portfolio.

# %% [markdown]
# Delete those rows which do not have Returns

# %%
crsp_data.dropna(subset = ['RET'], inplace=True)

# %%
crsp_data.isnull().sum()
# Out:
# PERMNO                   0
# date                     0
# SHRCD                    0
# SICCD                    0
# TICKER                3034
# COMNAM                   0
# PERMCO                   0
# CUSIP                    0
# DLRETX             2195640
# DLRET              2195640
# PRC                  12451
# RET                      0
# SHROUT                   0
# RETX                     0
# year_x                   0
# month                    0
# market_cap           12451
# fyear                    0
# BMR                   8723
# portfolio_year           0
# portfolio_month          0
# year_y                   0
# Size                     0
# Value                    0
# port_weights             0
# dtype: int64

# %% [markdown]
# ## Your portfolio weights change every month because of the last month returns

# %%
port_data = crsp_data.ix[:,['PERMNO','PERMCO','RET','port_weights','portfolio_year','portfolio_month']]

# %% [markdown]
# Sort by Portfolio year and month before using groupby and shift

# %%
port_data.sort_values(by = ['PERMCO', 'PERMNO','portfolio_year', 'portfolio_month'], inplace=True)

# %%
port_data['del_ret'] = port_data.groupby(['PERMCO','PERMNO','portfolio_year',])['RET'].shift(1)+1

# %%
port_data.ix[port_data.portfolio_month == 1,'del_ret'] = 1

# %%
port_data['cum_ret'] = port_data.groupby(['PERMCO','PERMNO','portfolio_year'])['del_ret'].cumprod()

# %%
port_data.dropna(subset=['cum_ret'], inplace=True)

# %% [markdown]
# ## Merge cum_ret of port_data with crsp_data

# %%
crsp_data = pd.merge(crsp_data, port_data[['PERMNO','PERMCO','portfolio_year','portfolio_month','cum_ret']])

# %%
crsp_data.dropna(subset =['port_weights','cum_ret','market_cap'], inplace=True)

# %%
crsp_data['port_weights'] = crsp_data.port_weights *crsp_data.cum_ret

# %%
penul_data = crsp_data.groupby(['year_x','month','Size',
                          'Value'])[['RET','port_weights']].apply(lambda g:np.average(g['RET'], weights=g['port_weights']))

# %%
ultimate = penul_data.unstack('Size').unstack('Value').reset_index().sort_values(by=['year_x','month'])

# %%
ultimate.columns = [' '.join(col).strip() for col in ultimate.columns.values]

# %%
ultimate['SMB'] =1/3*(ultimate['Small Growth']+ultimate['Small Value']+ultimate['Small Neutral']) -\
                1/3*(ultimate['Big Growth']+ultimate['Big Value']+ultimate['Big Neutral'])

# %%
ultimate['SMB_Perc'] = ultimate['SMB']*100

# %%
ultimate['HML'] = (0.5*(ultimate['Big Value']+ultimate['Small Value']) - \
                   0.5*(ultimate['Big Growth']+ultimate['Small Growth'])  )*100

# %%
crsp_data.cum_ret.isnull().sum()
# Out:
# 0

# %%
ultimate[ultimate.year_x>=1970].to_csv("factor.csv")

# %%
ultimate.ix[ultimate.year_x == 1970]
# Out:
#      year_x  month  Big Growth  Big Neutral  Big Value  Small Growth  Small Neutral  Small Value       SMB  SMB_Perc       HML
# 102    1970      1   -0.079762    -0.090284  -0.064485     -0.073181      -0.070267    -0.037066  0.018006  1.800561  2.569600
# 103    1970      2    0.038192     0.077874   0.079642      0.035726       0.044845     0.064075 -0.017021 -1.702116  3.489987
# 104    1970      3   -0.018210     0.014748   0.013263     -0.036278       0.001339     0.015010 -0.009910 -0.991000  4.138075
# 105    1970      4   -0.094792    -0.091676  -0.075648     -0.194109      -0.130785    -0.102539 -0.055106 -5.510593  5.535689
# 106    1970      5   -0.073884    -0.038998  -0.038491     -0.102615      -0.098851    -0.071959 -0.040684 -4.068418  3.302483
# 107    1970      6   -0.058805    -0.028558  -0.061782     -0.058147      -0.056802    -0.064418 -0.010074 -1.007436 -0.462415
# 108    1970      7    0.042988     0.097625   0.091686      0.082947       0.074833     0.082921  0.002800  0.280031  2.433623
# 109    1970      8    0.039644     0.055627   0.046372      0.071198       0.069235     0.059200  0.019330  1.933010 -0.263560
# 110    1970      9    0.068748     0.006237   0.012499      0.128817       0.081692     0.078055  0.067027  6.702704 -5.350519
# 111    1970     10    0.000171    -0.007188  -0.021429     -0.043978      -0.054344    -0.053686 -0.041187 -4.118715 -1.565358
# 112    1970     11    0.050547     0.057397   0.062596      0.029275       0.041755     0.036833 -0.020892 -2.089202  0.980326
# 113    1970     12    0.049477     0.061958   0.063968      0.061926       0.093139     0.112931  0.030865  3.086452  3.274812

# %%
1/3*(-0.082037-0.052705-0.081341) - 1/3*(-0.063200-0.020646-0.027509)
# Out:
# -0.03490933333333332

# %%
compustat_data[compustat_data.PERMNO == 16598]
# Out:
#        PERMNO  PERMCO  fyear      seq  year  market_cap       BMR
# 2973    16598   22702   1967  125.778  1967  531.247500  0.236760
# 4457    16598   22702   1968  122.293  1968  474.609000  0.257671
# 6002    16598   22702   1969  123.956  1969  258.589125  0.479355
# 6823    16598   22702   1970  129.407  1970  280.560750  0.461244
# 9161    16598   22702   1971  156.314  1971  263.879000  0.592370
# 10812   16598   22702   1972  160.126  1972  203.333250  0.787505
# 12619   16598   22702   1973  164.346  1973  105.233875  1.561721
# 17387   16598   22702   1974  183.280  1974  103.450250  1.771673
# 21900   16598   22702   1975  194.685  1975  140.906375  1.381662
# 25765   16598   22702   1976  201.235  1976  165.877125  1.213157
# 29616   16598   22702   1977  234.723  1977  173.120750  1.355834
# 32204   16598   22702   1978  238.300  1978  159.964000  1.489710
# 35589   16598   22702   1979  280.097  1979  276.810250  1.011874
# 40225   16598   22702   1980  328.357  1980  437.926125  0.749800

# %%
crsp_data[crsp_data.PERMNO == 16598]
# Out:
#         PERMNO       date  SHRCD SICCD TICKER                COMNAM  PERMCO     CUSIP  DLRETX  DLRET     PRC       RET  SHROUT      RETX  year_x  month  market_cap  fyear       BMR  portfolio_year  portfolio_month  year_y   Size    Value  port_weights   cum_ret
# 253890   16598 1968-07-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  33.000 -0.098976   13492 -0.098976    1968      7  445.236000   1967  0.236760            1968                1    1968    Big   Growth      0.002902  1.000000
# 253891   16598 1968-08-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  35.875  0.087121   13492  0.087121    1968      8  484.025500   1967  0.236760            1968                2    1968    Big   Growth      0.002615  0.901024
# 253892   16598 1968-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  36.875  0.036237   13492  0.027875    1968      9  497.517500   1967  0.236760            1968                3    1968    Big   Growth      0.002842  0.979522
# 253893   16598 1968-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  38.000  0.030508   13492  0.030508    1968     10  512.696000   1967  0.236760            1968                4    1968    Big   Growth      0.002945  1.015017
# 253894   16598 1968-11-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  39.500  0.039474   13492  0.039474    1968     11  532.934000   1967  0.236760            1968                5    1968    Big   Growth      0.003035  1.045983
# 253895   16598 1968-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  35.125 -0.103165   13512 -0.110759    1968     12  474.609000   1967  0.236760            1968                6    1968    Big   Growth      0.003155  1.087272
# 253896   16598 1969-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  29.500 -0.160142   13512 -0.160142    1969      1  398.604000   1968  0.257671            1968                7    1968    Big   Growth      0.002830  0.975104
# 253897   16598 1969-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  29.375 -0.004237   13512 -0.004237    1969      2  396.915000   1968  0.257671            1968                8    1968    Big   Growth      0.002376  0.818949
# 253898   16598 1969-03-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  26.500 -0.087660   13512 -0.097872    1969      3  358.068000   1968  0.257671            1968                9    1968    Big   Growth      0.002366  0.815479
# 253899   16598 1969-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  27.000  0.018868   13512  0.018868    1969      4  364.824000   1968  0.257671            1968               10    1968    Big   Growth      0.002159  0.743994
# 253900   16598 1969-05-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  24.000 -0.111111   13512 -0.111111    1969      5  324.288000   1968  0.257671            1968               11    1968    Big   Growth      0.002200  0.758032
# 253901   16598 1969-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  21.000 -0.112500   13512 -0.125000    1969      6  283.752000   1968  0.257671            1968               12    1968    Big   Growth      0.001955  0.673806
# 253902   16598 1969-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  20.000 -0.047619   13512 -0.047619    1969      7  270.240000   1968  0.257671            1969                1    1969  Small   Growth      0.009224  1.000000
# 253903   16598 1969-08-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.375 -0.081250   13512 -0.081250    1969      8  248.283000   1968  0.257671            1969                2    1969  Small   Growth      0.008785  0.952381
# 253904   16598 1969-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.250  0.004082   13512 -0.006803    1969      9  246.594000   1968  0.257671            1969                3    1969  Small   Growth      0.008071  0.875000
# 253905   16598 1969-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  20.500  0.123288   13512  0.123288    1969     10  276.996000   1968  0.257671            1969                4    1969  Small   Growth      0.008104  0.878572
# 253906   16598 1969-11-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.000 -0.073171   13512 -0.073171    1969     11  256.728000   1968  0.257671            1969                5    1969  Small   Growth      0.009103  0.986889
# 253907   16598 1969-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.125  0.017105   13521  0.006579    1969     12  258.589125   1968  0.257671            1969                6    1969  Small   Growth      0.008437  0.914677
# 253908   16598 1970-01-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.000 -0.006536   13521 -0.006536    1970      1  256.899000   1969  0.479355            1969                7    1969  Small   Growth      0.008581  0.930323
# 253909   16598 1970-02-27     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  21.375  0.125000   13521  0.125000    1970      2  289.011375   1969  0.479355            1969                8    1969  Small   Growth      0.008525  0.924242
# 253910   16598 1970-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  24.375  0.149708   13521  0.140351    1970      3  329.574375   1969  0.479355            1969                9    1969  Small   Growth      0.009591  1.039773
# 253911   16598 1970-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.000 -0.220513   13521 -0.220513    1970      4  256.899000   1969  0.479355            1969               10    1969  Small   Growth      0.011027  1.195435
# 253912   16598 1970-05-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.625 -0.072368   13521 -0.072368    1970      5  238.307625   1969  0.479355            1969               11    1969  Small   Growth      0.008595  0.931826
# 253913   16598 1970-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  15.125 -0.130496   13521 -0.141844    1970      6  204.505125   1969  0.479355            1969               12    1969  Small   Growth      0.007973  0.864392
# 253914   16598 1970-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.625  0.231405   13521  0.231405    1970      7  251.828625   1969  0.479355            1970                1    1970  Small   Growth      0.009681  1.000000
# 253915   16598 1970-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.875  0.067114   13521  0.067114    1970      8  268.729875   1969  0.479355            1970                2    1970  Small   Growth      0.011921  1.231405
# 253916   16598 1970-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.500 -0.008805   13521 -0.018868    1970      9  263.659500   1969  0.479355            1970                3    1970  Small   Growth      0.012721  1.314050
# 253917   16598 1970-10-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  21.375  0.096154   13521  0.096154    1970     10  289.011375   1969  0.479355            1970                4    1970  Small   Growth      0.012609  1.302479
# 253918   16598 1970-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.750 -0.076023   13521 -0.076023    1970     11  267.039750   1969  0.479355            1970                5    1970  Small   Growth      0.013821  1.427718
# 253919   16598 1970-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  20.750  0.060759   13521  0.050633    1970     12  280.560750   1969  0.479355            1970                6    1970  Small   Growth      0.012770  1.319179
# 253920   16598 1971-01-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  23.375  0.126506   13521  0.126506    1971      1  316.053375   1970  0.461244            1970                7    1970  Small   Growth      0.013546  1.399330
# 253921   16598 1971-02-26     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  21.500 -0.080214   13521 -0.080214    1971      2  290.701500   1970  0.461244            1970                8    1970  Small   Growth      0.015260  1.576354
# 253922   16598 1971-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  22.750  0.067442   13521  0.058140    1971      3  307.602750   1970  0.461244            1970                9    1970  Small   Growth      0.014036  1.449909
# 253923   16598 1971-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  21.375 -0.060440   13521 -0.060440    1971      4  289.011375   1970  0.461244            1970               10    1970  Small   Growth      0.014982  1.547693
# 253924   16598 1971-05-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.625 -0.081871   13521 -0.081871    1971      5  265.349625   1970  0.461244            1970               11    1970  Small   Growth      0.014077  1.454151
# 253925   16598 1971-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.250 -0.008917   13521 -0.019108    1971      6  260.279250   1970  0.461244            1970               12    1970  Small   Growth      0.012924  1.335098
# 253926   16598 1971-07-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.625 -0.032468   13521 -0.032468    1971      7  251.828625   1970  0.461244            1971                1    1971  Small   Growth      0.005995  1.000000
# 253927   16598 1971-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  20.500  0.100671   13521  0.100671    1971      8  277.180500   1970  0.461244            1971                2    1971  Small   Growth      0.005800  0.967532
# 253928   16598 1971-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.500 -0.087805   13521 -0.097561    1971      9  250.138500   1970  0.461244            1971                3    1971  Small   Growth      0.006384  1.064934
# 253929   16598 1971-10-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  15.750 -0.148649   13521 -0.148649    1971     10  212.955750   1970  0.461244            1971                4    1971  Small   Growth      0.005824  0.971428
# 253930   16598 1971-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.500  0.047619   13521  0.047619    1971     11  223.096500   1970  0.461244            1971                5    1971  Small   Growth      0.004958  0.827026
# 253931   16598 1971-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.625  0.140909   14168  0.128788    1971     12  263.879000   1970  0.461244            1971                6    1971  Small   Growth      0.005194  0.866408
# 253932   16598 1972-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  19.000  0.020134   14168  0.020134    1972      1  269.192000   1971  0.592370            1971                7    1971  Small   Growth      0.005926  0.988493
# 253933   16598 1972-02-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.000 -0.052632   14168 -0.052632    1972      2  255.024000   1971  0.592370            1971                8    1971  Small   Growth      0.006045  1.008395
# 253934   16598 1972-03-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  18.000  0.011111   14168  0.000000    1972      3  255.024000   1971  0.592370            1971                9    1971  Small   Growth      0.005727  0.955321
# 253935   16598 1972-04-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.625 -0.076389   14168 -0.076389    1972      4  235.543000   1971  0.592370            1971               10    1971  Small   Growth      0.005791  0.965936
# 253936   16598 1972-05-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.000  0.022556   14168  0.022556    1972      5  240.856000   1971  0.592370            1971               11    1971  Small   Growth      0.005348  0.892149
# 253937   16598 1972-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.875 -0.113235   14168 -0.125000    1972      6  210.749000   1971  0.592370            1971               12    1971  Small   Growth      0.005469  0.912272
# 253938   16598 1972-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.625 -0.084034   14168 -0.084034    1972      7  193.039000   1971  0.592370            1972                1    1972  Small  Neutral      0.004594  1.000000
# 253939   16598 1972-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.875  0.018349   14168  0.018349    1972      8  196.581000   1971  0.592370            1972                2    1972  Small  Neutral      0.004208  0.915966
# 253940   16598 1972-09-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.000  0.023423   14168  0.009009    1972      9  198.352000   1971  0.592370            1972                3    1972  Small  Neutral      0.004285  0.932773
# 253941   16598 1972-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.750 -0.017857   14168 -0.017857    1972     10  194.810000   1971  0.592370            1972                4    1972  Small  Neutral      0.004386  0.954621
# 253942   16598 1972-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.625  0.209091   14168  0.209091    1972     11  235.543000   1971  0.592370            1972                5    1972  Small  Neutral      0.004307  0.937575
# 253943   16598 1972-12-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.250 -0.130827   14269 -0.142857    1972     12  203.333250   1971  0.592370            1972                6    1972  Small  Neutral      0.005208  1.133613
# 253944   16598 1973-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.875 -0.026316   14269 -0.026316    1973      1  197.982375   1972  0.787505            1972                7    1972  Small  Neutral      0.004527  0.985306
# 253945   16598 1973-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.125 -0.126126   14269 -0.126126    1973      2  173.011625   1972  0.787505            1972                8    1972  Small  Neutral      0.004407  0.959377
# 253946   16598 1973-03-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.250 -0.055670   14269 -0.072165    1973      3  160.526250   1972  0.787505            1972                9    1972  Small  Neutral      0.003852  0.838374
# 253947   16598 1973-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.000 -0.022222   14269 -0.022222    1973      4  156.959000   1972  0.787505            1972               10    1972  Small  Neutral      0.003637  0.791702
# 253948   16598 1973-05-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.500 -0.136364   14269 -0.136364    1973      5  135.555500   1972  0.787505            1972               11    1972  Small  Neutral      0.003556  0.774109
# 253949   16598 1973-06-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.000 -0.039474   14269 -0.052632    1973      6  128.421000   1972  0.787505            1972               12    1972  Small  Neutral      0.003071  0.668548
# 253950   16598 1973-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.000  0.000000   14269  0.000000    1973      7  128.421000   1972  0.787505            1973                1    1973  Small  Neutral      0.003931  1.000000
# 253951   16598 1973-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.875 -0.013889   14269 -0.013889    1973      8  126.637375   1972  0.787505            1973                2    1973  Small  Neutral      0.003931  1.000000
# 253952   16598 1973-09-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.125  0.154930   14269  0.140845    1973      9  144.473625   1972  0.787505            1973                3    1973  Small  Neutral      0.003876  0.986111
# 253953   16598 1973-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.750  0.061728   14269  0.061728    1973     10  153.391750   1972  0.787505            1973                4    1973  Small  Neutral      0.004476  1.138889
# 253954   16598 1973-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.125 -0.244186   14269 -0.244186    1973     11  115.935625   1972  0.787505            1973                5    1973  Small  Neutral      0.004753  1.209191
# 253955   16598 1973-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   7.375 -0.076923   14269 -0.092308    1973     12  105.233875   1972  0.787505            1973                6    1973  Small  Neutral      0.003592  0.913923
# 253956   16598 1974-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.500  0.288136   14269  0.288136    1974      1  135.555500   1973  1.561721            1973                7    1973  Small  Neutral      0.003316  0.843621
# 253957   16598 1974-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.750  0.026316   14269  0.026316    1974      2  139.122750   1973  1.561721            1973                8    1973  Small  Neutral      0.004271  1.086699
# 253958   16598 1974-03-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.875  0.025641   14269  0.012821    1974      3  140.906375   1973  1.561721            1973                9    1973  Small  Neutral      0.004384  1.115297
# 253959   16598 1974-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.750 -0.113924   14269 -0.113924    1974      4  124.853750   1973  1.561721            1973               10    1973  Small  Neutral      0.004496  1.143894
# 253960   16598 1974-05-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.000 -0.085714   14269 -0.085714    1974      5  114.152000   1973  1.561721            1973               11    1973  Small  Neutral      0.003984  1.013577
# 253961   16598 1974-06-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.375  0.062500   14269  0.046875    1974      6  119.502875   1973  1.561721            1973               12    1973  Small  Neutral      0.003642  0.926699
# 253962   16598 1974-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.875  0.059701   14269  0.059701    1974      7  126.637375   1973  1.561721            1974                1    1974  Small  Neutral      0.004233  1.000000
# 253963   16598 1974-08-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   7.750 -0.126761   14269 -0.126761    1974      8  110.584750   1973  1.561721            1974                2    1974  Small  Neutral      0.004486  1.059701
# 253964   16598 1974-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   7.750  0.020645   14269  0.000000    1974      9  110.584750   1973  1.561721            1974                3    1974  Small  Neutral      0.003917  0.925372
# 253965   16598 1974-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.625  0.112903   14269  0.112903    1974     10  123.070125   1973  1.561721            1974                4    1974  Small  Neutral      0.003998  0.944477
# 253966   16598 1974-11-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   7.875 -0.086957   14269 -0.086957    1974     11  112.368375   1973  1.561721            1974                5    1974  Small  Neutral      0.004449  1.051111
# 253967   16598 1974-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   7.250 -0.059048   14269 -0.079365    1974     12  103.450250   1973  1.561721            1974                6    1974  Small  Neutral      0.004062  0.959709
# 253968   16598 1975-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   8.625  0.189655   14269  0.189655    1975      1  123.070125   1974  1.771673            1974                7    1974  Small  Neutral      0.003822  0.903040
# 253969   16598 1975-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.000  0.043478   14269  0.043478    1975      2  128.421000   1974  1.771673            1974                8    1974  Small  Neutral      0.004547  1.074307
# 253970   16598 1975-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.125  0.145000   14269  0.125000    1975      3  144.473625   1974  1.771673            1974                9    1974  Small  Neutral      0.004745  1.121015
# 253971   16598 1975-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.875  0.074074   14269  0.074074    1975      4  155.175375   1974  1.771673            1974               10    1974  Small  Neutral      0.005433  1.283562
# 253972   16598 1975-05-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.875  0.000000   14269  0.000000    1975      5  155.175375   1974  1.771673            1974               11    1974  Small  Neutral      0.005836  1.378641
# 253973   16598 1975-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.250  0.142989   14269  0.126437    1975      6  174.795250   1974  1.771673            1974               12    1974  Small  Neutral      0.005836  1.378641
# 253974   16598 1975-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.500 -0.061224   14269 -0.061224    1975      7  164.093500   1974  1.771673            1975                1    1975    Big    Value      0.001706  1.000000
# 253975   16598 1975-08-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.500 -0.086957   14269 -0.086957    1975      8  149.824500   1974  1.771673            1975                2    1975    Big    Value      0.001601  0.938776
# 253976   16598 1975-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.875 -0.042381   14269 -0.059524    1975      9  140.906375   1974  1.771673            1975                3    1975    Big    Value      0.001462  0.857143
# 253977   16598 1975-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.625 -0.025316   14269 -0.025316    1975     10  137.339125   1974  1.771673            1975                4    1975    Big    Value      0.001400  0.820816
# 253978   16598 1975-11-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.125  0.051948   14269  0.051948    1975     11  144.473625   1974  1.771673            1975                5    1975    Big    Value      0.001365  0.800036
# 253979   16598 1975-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN   9.875 -0.006914   14269 -0.024691    1975     12  140.906375   1974  1.771673            1975                6    1975    Big    Value      0.001435  0.841597
# 253980   16598 1976-01-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.125  0.227848   14269  0.227848    1976      1  173.011625   1975  1.381662            1975                7    1975    Big    Value      0.001425  0.835778
# 253981   16598 1976-02-27     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.375  0.020619   14269  0.020619    1976      2  176.578875   1975  1.381662            1975                8    1975    Big    Value      0.001750  1.026208
# 253982   16598 1976-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.500 -0.056162   14269 -0.070707    1976      3  164.093500   1975  1.381662            1975                9    1975    Big    Value      0.001786  1.047368
# 253983   16598 1976-04-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.750 -0.065217   14269 -0.065217    1976      4  153.391750   1975  1.381662            1975               10    1975    Big    Value      0.001686  0.988545
# 253984   16598 1976-05-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.000  0.023256   14269  0.023256    1976      5  156.959000   1975  1.381662            1975               11    1975    Big    Value      0.001576  0.924075
# 253985   16598 1976-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.375  0.050455   14269  0.034091    1976      6  162.309875   1975  1.381662            1975               12    1975    Big    Value      0.001613  0.945566
# 253986   16598 1976-07-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.250 -0.010989   14269 -0.010989    1976      7  160.526250   1975  1.381662            1976                1    1976    Big    Value      0.001208  1.000000
# 253987   16598 1976-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.375  0.011111   14269  0.011111    1976      8  162.309875   1975  1.381662            1976                2    1976    Big    Value      0.001195  0.989011
# 253988   16598 1976-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.250 -0.083077   14269 -0.098901    1976      9  146.257250   1975  1.381662            1976                3    1976    Big    Value      0.001208  1.000000
# 253989   16598 1976-10-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.000 -0.024390   14269 -0.024390    1976     10  142.690000   1975  1.381662            1976                4    1976    Big    Value      0.001108  0.916923
# 253990   16598 1976-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.625  0.062500   14269  0.062500    1976     11  151.608125   1975  1.381662            1976                5    1976    Big    Value      0.001081  0.894559
# 253991   16598 1976-12-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.625  0.111059   14269  0.094118    1976     12  165.877125   1975  1.381662            1976                6    1976    Big    Value      0.001148  0.950469
# 253992   16598 1977-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.250  0.053763   14269  0.053763    1977      1  174.795250   1976  1.213157            1976                7    1976    Big    Value      0.001276  1.056027
# 253993   16598 1977-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  10.625 -0.132653   14269 -0.132653    1977      2  151.608125   1976  1.213157            1976                8    1976    Big    Value      0.001344  1.112802
# 253994   16598 1977-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.000  0.052235   14269  0.035294    1977      3  156.959000   1976  1.213157            1976                9    1976    Big    Value      0.001166  0.965186
# 253995   16598 1977-04-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.625  0.147727   14269  0.147727    1977      4  180.146125   1976  1.213157            1976               10    1976    Big    Value      0.001227  1.015602
# 253996   16598 1977-05-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.375 -0.019802   14269 -0.019802    1977      5  176.578875   1976  1.213157            1976               11    1976    Big    Value      0.001408  1.165634
# 253997   16598 1977-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.000  0.065050   14274  0.050505    1977      6  185.562000   1976  1.213157            1976               12    1976    Big    Value      0.001380  1.142552
# 253998   16598 1977-07-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  13.750  0.057692   14274  0.057692    1977      7  196.267500   1976  1.213157            1977                1    1977    Big    Value      0.001230  1.000000
# 253999   16598 1977-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.250 -0.094182   14274 -0.109091    1977      8  174.856500   1976  1.213157            1977                2    1977    Big    Value      0.001301  1.057692
# 254000   16598 1977-09-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.625  0.030612   14277  0.030612    1977      9  180.247125   1976  1.213157            1977                3    1977    Big    Value      0.001179  0.958076
# 254001   16598 1977-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.000 -0.049505   14277 -0.049505    1977     10  171.324000   1976  1.213157            1977                4    1977    Big    Value      0.001215  0.987405
# 254002   16598 1977-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.375  0.048333   14277  0.031250    1977     11  176.677875   1976  1.213157            1977                5    1977    Big    Value      0.001155  0.938524
# 254003   16598 1977-12-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.125 -0.020202   14278 -0.020202    1977     12  173.120750   1976  1.213157            1977                6    1977    Big    Value      0.001211  0.983885
# 254004   16598 1978-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  11.750 -0.030928   14278 -0.030928    1978      1  167.766500   1977  1.355834            1977                7    1977    Big    Value      0.001186  0.964009
# 254005   16598 1978-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  12.500  0.085106   14278  0.063830    1978      2  178.475000   1977  1.355834            1977                8    1977    Big    Value      0.001149  0.934194
# 254006   16598 1978-03-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.875  0.190000   14278  0.190000    1978      3  212.385250   1977  1.355834            1977                9    1977    Big    Value      0.001247  1.013699
# 254007   16598 1978-04-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.250  0.092437   14278  0.092437    1978      4  232.017500   1977  1.355834            1977               10    1977    Big    Value      0.001484  1.206302
# 254008   16598 1978-05-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.625  0.038462   14278  0.023077    1978      5  237.371750   1977  1.355834            1977               11    1977    Big    Value      0.001621  1.317809
# 254009   16598 1978-06-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.625  0.060150   14278  0.060150    1978      6  251.649750   1977  1.355834            1977               12    1977    Big    Value      0.001684  1.368495
# 254010   16598 1978-07-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.875  0.014184   14289  0.014184    1978      7  255.415875   1977  1.355834            1978                1    1978    Big    Value      0.001645  1.000000
# 254011   16598 1978-08-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  20.500  0.162238   14289  0.146853    1978      8  292.924500   1977  1.355834            1978                2    1978    Big    Value      0.001668  1.014184
# 254012   16598 1978-09-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.750 -0.134146   11420 -0.134146    1978      9  202.705000   1977  1.355834            1978                3    1978    Big    Value      0.001939  1.178723
# 254013   16598 1978-10-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.500 -0.183099   11420 -0.183099    1978     10  165.590000   1977  1.355834            1978                4    1978    Big    Value      0.001679  1.020602
# 254014   16598 1978-11-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.625  0.027586   11420  0.008621    1978     11  167.017500   1977  1.355834            1978                5    1978    Big    Value      0.001371  0.833731
# 254015   16598 1978-12-29     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  14.000 -0.042735   11426 -0.042735    1978     12  159.964000   1977  1.355834            1978                6    1978    Big    Value      0.001409  0.856730
# 254016   16598 1979-01-31     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  16.500  0.178571   11426  0.178571    1979      1  188.529000   1978  1.489710            1978                7    1978    Big    Value      0.001349  0.820118
# 254017   16598 1979-02-28     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  15.625 -0.036364   11426 -0.053030    1979      2  178.531250   1978  1.489710            1978                8    1978    Big    Value      0.001590  0.966567
# 254018   16598 1979-03-30     10  3357     GK    GENERAL CABLE CORP   22702  36176510     NaN    NaN  17.750  0.136000   11426  0.136000    1979      3  202.811500   1978  1.489710            1978                9    1978    Big    Value      0.001532  0.931419
# 254019   16598 1979-04-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  18.000  0.014085   11426  0.014085    1979      4  205.668000   1978  1.489710            1978               10    1978    Big    Value      0.001740  1.058092
# 254020   16598 1979-05-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  17.875  0.008333   11426 -0.006944    1979      5  204.239750   1978  1.489710            1978               11    1978    Big    Value      0.001765  1.072995
# 254021   16598 1979-06-29     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  18.375  0.027972   11431  0.027972    1979      6  210.044625   1978  1.489710            1978               12    1978    Big    Value      0.001780  1.081936
# 254022   16598 1979-07-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  22.250  0.210884   11431  0.210884    1979      7  254.339750   1978  1.489710            1979                1    1979  Small  Neutral      0.003813  1.000000
# 254023   16598 1979-08-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  20.750 -0.055056   11431 -0.067416    1979      8  237.193250   1978  1.489710            1979                2    1979  Small  Neutral      0.004617  1.210884
# 254024   16598 1979-09-28     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  22.000  0.060241   11437  0.060241    1979      9  251.614000   1978  1.489710            1979                3    1979  Small  Neutral      0.004363  1.144218
# 254025   16598 1979-10-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  20.500 -0.068182   11437 -0.068182    1979     10  234.458500   1978  1.489710            1979                4    1979  Small  Neutral      0.004625  1.213146
# 254026   16598 1979-11-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  23.375  0.156098   11437  0.140244    1979     11  267.339875   1978  1.489710            1979                5    1979  Small  Neutral      0.004310  1.130432
# 254027   16598 1979-12-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  24.125  0.032086   11474  0.032086    1979     12  276.810250   1978  1.489710            1979                6    1979  Small  Neutral      0.004983  1.306890
# 254028   16598 1980-01-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  26.750  0.108808   11474  0.108808    1980      1  306.929500   1979  1.011874            1979                7    1979  Small  Neutral      0.005143  1.348823
# 254029   16598 1980-02-29     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  25.875 -0.020561   11474 -0.032710    1980      2  296.889750   1979  1.011874            1979                8    1979  Small  Neutral      0.005702  1.495585
# 254030   16598 1980-03-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  22.375 -0.135266   11474 -0.135266    1980      3  256.730750   1979  1.011874            1979                9    1979  Small  Neutral      0.005585  1.464835
# 254031   16598 1980-04-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  24.125  0.078212   11474  0.078212    1980      4  276.810250   1979  1.011874            1979               10    1979  Small  Neutral      0.004830  1.266692
# 254032   16598 1980-05-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  26.125  0.096373   11474  0.082902    1980      5  299.758250   1979  1.011874            1979               11    1979  Small  Neutral      0.005207  1.365763
# 254033   16598 1980-06-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  26.500  0.014354   11693  0.014354    1980      6  309.864500   1979  1.011874            1979               12    1979  Small  Neutral      0.005709  1.497385
# 254034   16598 1980-07-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  40.125  0.514151   11693  0.514151    1980      7  469.181625   1979  1.011874            1980                1    1980    Big  Neutral      0.000785  1.000000
# 254035   16598 1980-08-29     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  40.875  0.028037   11693  0.018692    1980      8  477.951375   1979  1.011874            1980                2    1980    Big  Neutral      0.001189  1.514151
# 254036   16598 1980-09-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  42.875  0.048930   11693  0.048930    1980      9  501.337375   1979  1.011874            1980                3    1980    Big  Neutral      0.001222  1.556603
# 254037   16598 1980-10-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  44.000  0.026239   11693  0.026239    1980     10  514.492000   1979  1.011874            1980                4    1980    Big  Neutral      0.001282  1.632768
# 254038   16598 1980-11-28     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  38.875 -0.107955   11693 -0.116477    1980     11  454.565375   1979  1.011874            1980                5    1980    Big  Neutral      0.001316  1.675610
# 254039   16598 1980-12-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  35.875 -0.077170   12207 -0.077170    1980     12  437.926125   1979  1.011874            1980                6    1980    Big  Neutral      0.001174  1.494720
# 254040   16598 1981-01-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  35.250 -0.017422   12207 -0.017422    1981      1  430.296750   1980  0.749800            1980                7    1980    Big  Neutral      0.001083  1.379372
# 254041   16598 1981-02-27     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  48.250  0.379433   12207  0.368794    1981      2  588.987750   1980  0.749800            1980                8    1980    Big  Neutral      0.001064  1.355341
# 254042   16598 1981-03-31     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  49.250  0.020725   12207  0.020725    1981      3  601.194750   1980  0.749800            1980                9    1980    Big  Neutral      0.001468  1.869602
# 254043   16598 1981-04-30     10  3357     GK  G K TECHNOLOGIES INC   22702  36176510     NaN    NaN  49.625  0.007614   12731  0.007614    1981      4  631.775875   1980  0.749800            1980               10    1980    Big  Neutral      0.001498  1.908349
